# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
ny_estate = pd.read_csv('../data/NY-House-Dataset.csv')
ny_estate.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %%
ny_estate['SUBLOCALITY'].unique()
# Out:
# array(['Manhattan', 'New York County', 'Richmond County', 'Kings County',
#        'New York', 'East Bronx', 'Brooklyn', 'The Bronx', 'Queens',
#        'Staten Island', 'Queens County', 'Bronx County', 'Coney Island',
#        'Brooklyn Heights', 'Jackson Heights', 'Riverdale', 'Rego Park',
#        'Fort Hamilton', 'Flushing', 'Dumbo', 'Snyder Avenue'],
#       dtype=object)

# %%
data = pd.read_csv('../data/0116_superstore.csv')
data.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156  2017-11-08  2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156  2017-11-08  2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688  2017-06-12  2017-06-16    Second Class    DV-13045
# 3  US-2016-108966  2016-10-11  2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966  2016-10-11  2016-10-18  Standard Class    SO-20335
#
#      Segment        Country             City       State  Postal Code Region  \
# 0   Consumer  United States        Henderson    Kentucky        42420  South
# 1   Consumer  United States        Henderson    Kentucky        42420  South
# 2  Corporate  United States      Los Angeles  California        90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida        33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida        33311  South
#
#         Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# > 뉴욕 데이터만 분리

# %%
ny_data = data[data['State']=='New York']
ny_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1097 entries, 53 to 9781
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1097 non-null   object
#  1   Order Date         1097 non-null   object
#  2   Ship Date          1097 non-null   object
#  3   Ship Mode          1097 non-null   object
#  4   Customer ID        1097 non-null   object
#  5   Segment            1097 non-null   object
#  6   Country            1097 non-null   object
#  7   City               1097 non-null   object
#  8   State              1097 non-null   object
#  9   Postal Code        1097 non-null   int64
#  10  Region             1097 non-null   object
#  11  Product ID         1097 non-null   object
#  12  Category           1097 non-null   object
#  13  Sub-Category       1097 non-null   object
#  14  Product Name       1097 non-null   object
#  15  Sales              1097 non-null   float64
# ...

# %%
len(ny_data['Order ID'].unique())
# Out:
# 547

# %%
ny_data.head()
# Out:
#           Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 53  CA-2017-105816  2017-12-11  2017-12-17  Standard Class    JM-15265
# 54  CA-2017-105816  2017-12-11  2017-12-17  Standard Class    JM-15265
# 55  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 56  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 57  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
#
#       Segment        Country           City     State  Postal Code Region  \
# 53  Corporate  United States  New York City  New York        10024   East
# 54  Corporate  United States  New York City  New York        10024   East
# 55   Consumer  United States           Troy  New York        12180   East
# 56   Consumer  United States           Troy  New York        12180   East
# 57   Consumer  United States           Troy  New York        12180   East
#
#          Product ID         Category Sub-Category  \
# ...

# %%
ny_data.drop(
    ['Country', 'State', 'Region', 'unique_city'],
    axis=1,
    inplace=True
)
# Out:
# /var/folders/r4/77bfg6f94ylc4fbsrpn6kvc40000gn/T/ipykernel_2027/385281861.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny_data.drop(

# %%
ny_data.head()
# Out:
#           Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 53  CA-2017-105816  2017-12-11  2017-12-17  Standard Class    JM-15265
# 54  CA-2017-105816  2017-12-11  2017-12-17  Standard Class    JM-15265
# 55  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 56  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 57  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
#
#       Segment           City  Postal Code       Product ID         Category  \
# 53  Corporate  New York City        10024  OFF-FA-10000304  Office Supplies
# 54  Corporate  New York City        10024  TEC-PH-10002447       Technology
# 55   Consumer           Troy        12180  OFF-ST-10000604  Office Supplies
# 56   Consumer           Troy        12180  OFF-PA-10001569  Office Supplies
# 57   Consumer           Troy        12180  FUR-CH-10003968        Furniture
#
#    Sub-Category                      Product Name    Sales  Shipping Duration  \
# ...

# %%
ny_data['City'].unique()
# Out:
# array(['New York City', 'Troy', 'New Rochelle', 'Auburn', 'Lindenhurst',
#        'Rochester', 'Mount Vernon', 'Oceanside', 'Yonkers', 'Buffalo',
#        'Long Beach', 'Freeport', 'Niagara Falls', 'Watertown',
#        'Jamestown', 'Hempstead', 'Rome', 'Utica'], dtype=object)

# %% [markdown]
# ---
# - 부동산 데이터 Postal code 분리

# %%
ny_estate['Postal Code'] = ny_estate['STATE'].str[-5:]
ny_estate.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %%
len(ny_estate['Postal Code'].unique())
# Out:
# 178

# %%
len(ny_data['Postal Code'].unique())
# Out:
# 21

# %%
len(ny_data['Customer ID'].unique())
# Out:
# 409

# %%
ny_estate['TYPE'].unique()
# Out:
# array(['Condo for sale', 'House for sale', 'Townhouse for sale',
#        'Co-op for sale', 'Multi-family home for sale', 'For sale',
#        'Contingent', 'Land for sale', 'Foreclosure', 'Pending',
#        'Coming Soon', 'Mobile house for sale', 'Condop for sale'],
#       dtype=object)

# %%
ny_estate['LOCALITY'].unique()
# Out:
# array(['New York', 'New York County', 'The Bronx', 'Kings County',
#        'Bronx County', 'Queens County', 'Richmond County',
#        'United States', 'Brooklyn', 'Queens', 'Flatbush'], dtype=object)

# %%
ny_estate['SUBLOCALITY'].unique()
# Out:
# array(['Manhattan', 'New York County', 'Richmond County', 'Kings County',
#        'New York', 'East Bronx', 'Brooklyn', 'The Bronx', 'Queens',
#        'Staten Island', 'Queens County', 'Bronx County', 'Coney Island',
#        'Brooklyn Heights', 'Jackson Heights', 'Riverdale', 'Rego Park',
#        'Fort Hamilton', 'Flushing', 'Dumbo', 'Snyder Avenue'],
#       dtype=object)

# %%
ny_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4801 non-null   object
#  1   TYPE                         4801 non-null   object
#  2   PRICE                        4801 non-null   int64
#  3   BEDS                         4801 non-null   int64
#  4   BATH                         4801 non-null   float64
#  5   PROPERTYSQFT                 4801 non-null   float64
#  6   ADDRESS                      4801 non-null   object
#  7   STATE                        4801 non-null   object
#  8   MAIN_ADDRESS                 4801 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  10  LOCALITY                     4801 non-null   object
#  11  SUBLOCALITY                  4801 non-null   object
#  12  STREET_NAME                  4801 non-null   object
# ...

# %%
ny_estate[ny_estate['LOCALITY']=='United States']
# Out:
#                                             BROKERTITLE  \
# 27                  Brokered by Century 21 Realty First
# 58                     Brokered by American Homes Group
# 228       Brokered by Staten Island Premiere Properties
# 301          Brokered by Coldwell Banker American Homes
# 366                    Brokered by Nella Management Llc
# 416              Brokered by Sovereign Realty Of Ny Inc
# 641                   Brokered by M Holmes Realty Corp.
# 688           Brokered by CLAS - Classic Marketing, LLC
# 692       Brokered by Douglas Elliman - 575 Madison Ave
# 749             Brokered by Robert DeFalco Realty, Inc.
# 955                             Brokered by RE MAX Edge
# 1053                      Brokered by EXIT REALTY GROUP
# 1174                            Brokered by RE MAX Edge
# 1331           Brokered by TUDO - Tudor Realty Services
# 1562                     Brokered by Corcoran West Side
# 1828            Brokered by Robert Defalco Realty, Inc.
# ...

# %%
ny_data.to_csv('../data/ny_data.csv',index=False)

# %%
print(ny_data['Postal Code'].unique())
print(ny_estate['Postal Code'].unique())
# Out:
# [10024 12180 10009 10035 10801 13021 11757 14609 10011 10550 11572 10701
#  14215 11561 11520 14304 13601 14701 11550 13440 13501]
# ['10022' '10019' '10312' '10065' '11238' '10027' '10304' '10473' '11230'
#  '10451' '10303' '11372' '11373' '10014' '11377' '11209' '10471' '11374'
#  '10301' '11375' '10465' '10307' '11435' '11214' '10314' '11207' '11219'
#  '11355' '11249' '10453' '11204' '11421' '10012' '11358' '11419' '10013'
#  '11231' '11217' '10023' '11235' '10002' '11218' '10306' '10308' '10075'
#  '11221' '11237' '11357' '10305' '11385' '10466' '11422' '10128' '10010'
#  '11436' '11234' '10025' '11210' '10021' '10463' '10469' '10470' '10309'
#  '11229' '11215' '10029' '10031' '11228' '10467' '11208' '11417' '11413'
#  '10032' '11691' '11426' '10007' '11360' '11103' '11005' '11365' '10458'
#  '10024' '11697' '10452' '11414' '11411' '11224' '11694' '10280' '11201'
#  '11369' '11362' '10474' '11354' '11415' '10038' '11105' '11216' '10302'
# ...

# %% [markdown]
# **New York 전체의 Postal Code 중 배송지의 Postal Code가 21개로 매우 적다.**
# - 산업단지 쪽에 배송지가 모여 있을 가능성?
# - 일반 소비자의 구매가 포함되었다기엔 주문 건수가 너무 적고, Postal Code가 주거지가 아닌 지역에 많다.

# %%
zipCode=ny_data['Postal Code'].unique()

# %% [markdown]
# > ny_data와 ny_estate의 Postal Code의 타입이 다르므로 int로 통일하기

# %%
ny_estate['Postal Code'] = ny_estate['Postal Code'].astype(int)

# %%
ny_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4801 non-null   object
#  1   TYPE                         4801 non-null   object
#  2   PRICE                        4801 non-null   int64
#  3   BEDS                         4801 non-null   int64
#  4   BATH                         4801 non-null   float64
#  5   PROPERTYSQFT                 4801 non-null   float64
#  6   ADDRESS                      4801 non-null   object
#  7   STATE                        4801 non-null   object
#  8   MAIN_ADDRESS                 4801 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  10  LOCALITY                     4801 non-null   object
#  11  SUBLOCALITY                  4801 non-null   object
#  12  STREET_NAME                  4801 non-null   object
# ...

# %%
filtered_ny_estate = ny_estate[ny_estate['Postal Code'].isin(ny_data['Postal Code'])]

# %%
filtered_ny_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, 139 to 4798
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  170 non-null    object
#  1   TYPE                         170 non-null    object
#  2   PRICE                        170 non-null    int64
#  3   BEDS                         170 non-null    int64
#  4   BATH                         170 non-null    float64
#  5   PROPERTYSQFT                 170 non-null    float64
#  6   ADDRESS                      170 non-null    object
#  7   STATE                        170 non-null    object
#  8   MAIN_ADDRESS                 170 non-null    object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  170 non-null    object
#  10  LOCALITY                     170 non-null    object
#  11  SUBLOCALITY                  170 non-null    object
#  12  STREET_NAME                  170 non-null    object
# ...

# %%
filtered_ny_estate.head()
# Out:
#                                            BROKERTITLE                TYPE  \
# 139                                Brokered by COMPASS  Townhouse for sale
# 143      Brokered by Douglas Elliman - 575 Madison Ave      Condo for sale
# 166                     Brokered by Corcoran East Side      Co-op for sale
# 212  Brokered by Byson Real Estate Company - Byson ...      Co-op for sale
# 221                                Brokered by COMPASS      Co-op for sale
#
#        PRICE  BEDS  BATH  PROPERTYSQFT                   ADDRESS  \
# 139  5000000    10   9.0   6425.000000             137 W 80th St
# 143   500000     4   3.0   1794.000000      251 W 89th St Apt 6E
# 166   550000     1   1.0   2184.207862  609 Columbus Ave Apt 10I
# 212  1525000     2   2.0   2184.207862    67 Riverside Dr Apt 1C
# 221   975000     3   1.0   2184.207862      360 W 22nd St Apt 9J
#
#                    STATE                                MAIN_ADDRESS  \
# ...

# %%
print(ny_data['Product Name'].unique())
print(ny_data['Product ID'].unique())
# Out:
# ['Advantus Push Pins' 'AT&T CL83451 4-Handset Telephone'
#  'Home/Office Personal File Carts' 'Xerox 232' 'Novimex Turbo Task Chair'
#  'Array Parchment Paper, Assorted Colors'
#  'Imation\xa08gb Micro Traveldrive Usb 2.0\xa0Flash Drive'
#  'Plastic Binding Combs' 'Prang Dustless Chalk Sticks'
#  'Avery Binding System Hidden Tab Executive Style Index Sets'
#  '9-3/4 Diameter Round Wall Clock' 'Magnifier Swing Arm Lamp'
#  'Sanford Colorific Eraseable Coloring Pencils, 12 Count'
#  'Atlantic Metals Mobile 4-Shelf Bookcases, Custom Colors'
#  "I Need's 3d Hello Kitty Hybrid Silicone Case Cover for HTC One X 4g with 3d Hello Kitty Stylus Pen Green/pink"
#  'Xerox 205' 'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors'
#  '4009 Highlighters by Sanford'
#  'Fellowes Personal Hanging Folder Files, Navy'
#  'Tyvek Side-Opening Peel & Seel Expanding Envelopes'
#  'Sabrent 4-Port USB 2.0 Hub' 'Safco Industrial Shelving'
#  'Acco 3-Hole Punch'
# ...

# %%
ny_data.head(10)
# Out:
#           Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 53  CA-2017-105816  2017-12-11  2017-12-17  Standard Class    JM-15265
# 54  CA-2017-105816  2017-12-11  2017-12-17  Standard Class    JM-15265
# 55  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 56  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 57  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 58  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 59  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 60  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 61  CA-2017-111682  2017-06-17  2017-06-18     First Class    TB-21055
# 70  CA-2017-106075  2017-09-18  2017-09-23  Standard Class    HM-14980
#
#       Segment           City  Postal Code       Product ID         Category  \
# 53  Corporate  New York City        10024  OFF-FA-10000304  Office Supplies
# ...

# %%
for code in zipCode:
    print(code,ny_estate.loc[ny_estate['Postal Code']==code, 'TYPE'].mode())
# Out:
# 10024 0    Co-op for sale
# Name: TYPE, dtype: object
# 12180 Series([], Name: TYPE, dtype: object)
# 10009 0    Co-op for sale
# Name: TYPE, dtype: object
# 10035 0        Co-op for sale
# 1    Townhouse for sale
# Name: TYPE, dtype: object
# 10801 Series([], Name: TYPE, dtype: object)
# 13021 Series([], Name: TYPE, dtype: object)
# 11757 Series([], Name: TYPE, dtype: object)
# 14609 Series([], Name: TYPE, dtype: object)
# 10011 0    Condo for sale
# Name: TYPE, dtype: object
# 10550 Series([], Name: TYPE, dtype: object)
# 11572 Series([], Name: TYPE, dtype: object)
# 10701 Series([], Name: TYPE, dtype: object)
# 14215 Series([], Name: TYPE, dtype: object)
# 11561 Series([], Name: TYPE, dtype: object)
# 11520 Series([], Name: TYPE, dtype: object)
# 14304 Series([], Name: TYPE, dtype: object)
# 13601 Series([], Name: TYPE, dtype: object)
# 14701 Series([], Name: TYPE, dtype: object)
# 11550 Series([], Name: TYPE, dtype: object)
# 13440 Series([], Name: TYPE, dtype: object)
# ...

# %% [markdown]
# > Co-op: Condo 느낌의 공유 주거지

# %%
ny_estate[ny_estate['Postal Code']==10550]
# Out:
# Empty DataFrame
# Columns: [BROKERTITLE, TYPE, PRICE, BEDS, BATH, PROPERTYSQFT, ADDRESS, STATE, MAIN_ADDRESS, ADMINISTRATIVE_AREA_LEVEL_2, LOCALITY, SUBLOCALITY, STREET_NAME, LONG_NAME, FORMATTED_ADDRESS, LATITUDE, LONGITUDE, Postal Code]
# Index: []

# %%
ny_data[ny_data['Postal Code']==10550]
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 712   US-2018-100048  2018-05-19  2018-05-24  Standard Class    RS-19765
# 713   US-2018-100048  2018-05-19  2018-05-24  Standard Class    RS-19765
# 714   US-2018-100048  2018-05-19  2018-05-24  Standard Class    RS-19765
# 4215  CA-2015-103590  2015-11-30  2015-12-04  Standard Class    JL-15505
# 5138  CA-2018-128335  2018-09-29  2018-10-05  Standard Class    JA-15970
# 5139  CA-2018-128335  2018-09-29  2018-10-05  Standard Class    JA-15970
# 6321  CA-2015-123316  2015-10-13  2015-10-17  Standard Class    SP-20545
# 8274  CA-2018-164112  2018-06-30  2018-07-04  Standard Class    ND-18460
#
#         Segment          City  Postal Code       Product ID         Category  \
# 712   Corporate  Mount Vernon        10550  OFF-AP-10001154  Office Supplies
# 713   Corporate  Mount Vernon        10550  TEC-PH-10003012       Technology
# 714   Corporate  Mount Vernon        10550  TEC-AC-10001606       Technology
# ...

# %% [markdown]
# > ny_data에 있는 Postal Code가 ny_estate 데이터에 없는 것이 훨씬 많다.
# > ny_estate 데이터는 주로 주거용 부동산 데이터여서 겹치지 않는 것 같다.

# %% [markdown]
# > ny_data에서 ny_estate에 postal code 정보가 없는 postal code를 갖는 data -> business building에 있는 data로 추측된다.

# %% [markdown]
# **Segment가 Consumer여도 회사용 물품을 구매했을 가능성이 높다고 판단된다.(배송지가 회사일 것으로 추측)**

# %%
sns.countplot(x='month', data=ny_data)
plt.show()

# %% [markdown]
# > 물품별 count

# %%
ny_group = ny_data[['Order ID', 'month', 'Weekday', 'Shipping Duration']]

# %%
grouped_df = ny_group.groupby('Order ID').agg({
    'month': 'first',
    'Weekday': 'first',
    'Shipping Duration': 'mean'
}).reset_index()

grouped_df.head()
# Out:
#          Order ID  month  Weekday  Shipping Duration
# 0  CA-2015-100006      9        6                6.0
# 1  CA-2015-100328      1        1                6.0
# 2  CA-2015-100391      5        4                4.0
# 3  CA-2015-101364     12        5                4.0
# 4  CA-2015-101476      9        6                1.0

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           547 non-null    object
#  1   month              547 non-null    int64
#  2   Weekday            547 non-null    int64
#  3   Shipping Duration  547 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 17.2+ KB

# %%
sns.countplot(x='month', data=grouped_df)
plt.show()

# %% [markdown]
# > Order ID(주문번호)별 count

# %%
ny_data['Order Date'] = pd.to_datetime(ny_data['Order Date'])
ny_data['Ship Date'] = pd.to_datetime(ny_data['Ship Date'])
# Out:
# /var/folders/r4/77bfg6f94ylc4fbsrpn6kvc40000gn/T/ipykernel_2027/1486569922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny_data['Order Date'] = pd.to_datetime(ny_data['Order Date'])
# /var/folders/r4/77bfg6f94ylc4fbsrpn6kvc40000gn/T/ipykernel_2027/1486569922.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny_data['Ship Date'] = pd.to_datetime(ny_data['Ship Date'])

# %%
ny_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1097 entries, 53 to 9781
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1097 non-null   object
#  1   Order Date         1097 non-null   datetime64[ns]
#  2   Ship Date          1097 non-null   datetime64[ns]
#  3   Ship Mode          1097 non-null   object
#  4   Customer ID        1097 non-null   object
#  5   Segment            1097 non-null   object
#  6   City               1097 non-null   object
#  7   Postal Code        1097 non-null   int64
#  8   Product ID         1097 non-null   object
#  9   Category           1097 non-null   object
#  10  Sub-Category       1097 non-null   object
#  11  Product Name       1097 non-null   object
#  12  Sales              1097 non-null   float64
#  13  Shipping Duration  1097 non-null   int64
#  14  lng                1097 non-null   float64
# ...

# %%
ny_data['year'] = ny_data['Ship Date'].dt.year

ny_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1097 entries, 53 to 9781
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1097 non-null   object
#  1   Order Date         1097 non-null   datetime64[ns]
#  2   Ship Date          1097 non-null   datetime64[ns]
#  3   Ship Mode          1097 non-null   object
#  4   Customer ID        1097 non-null   object
#  5   Segment            1097 non-null   object
#  6   City               1097 non-null   object
#  7   Postal Code        1097 non-null   int64
#  8   Product ID         1097 non-null   object
#  9   Category           1097 non-null   object
#  10  Sub-Category       1097 non-null   object
#  11  Product Name       1097 non-null   object
#  12  Sales              1097 non-null   float64
#  13  Shipping Duration  1097 non-null   int64
#  14  lng                1097 non-null   float64
# ...

# %%
sns.countplot(x='month', hue='year', data=ny_data)
plt.show()

# %%
ny_data = ny_data[ny_data['year']<=2018]
sns.countplot(x='month', hue='year', data=ny_data)
plt.show()

# %% [markdown]
# **2015~2018 허리케인 기간**
#
# 2015년:
#
# - 특별한 허리케인 활동이 보고되지 않음
#
# 2016년:
#
# - 9월 1일 ~ 10월 8일 (허리케인 Matthew가 미국 동부 해안을 강타)
#
# 2017년:
#
# - 8월 25일 ~ 9월 20일 (허리케인 Harvey, Irma, Maria가 연이어 미국을 강타)
#
# 2018년:
#
# - 5월 25일 ~ 10월 31일
# - 주요 허리케인:
#     - Florence: 8월 31일 ~ 9월 17일
#     - Michael: 10월 7일 ~ 10월 11일

# %% [markdown]
# > 허리케인 기간과 order count와 연관이 없어 보인다. Feature로 사용할 수 없을 것 같다.

# %% [markdown]
# ---
# > new york State의 배송 소요 기간 확인

# %%
standard_ship = ny_data[ny_data['Ship Mode']=='Standard Class']

average_shipping_duration = standard_ship.groupby('Postal Code')['Shipping Duration'].mean().reset_index()

# lng와 lat 정보 추가 (이미 데이터에 있다고 가정)
average_shipping_duration = average_shipping_duration.merge(
    ny_data[['Postal Code', 'lat', 'lng']].drop_duplicates(),
    on='Postal Code',
    how='left'
)

# %%
import folium
from folium.plugins import MarkerCluster

# 미국 중심 좌표로 지도 생성
us_map = folium.Map(location=[42.9538, -75.5268], zoom_start=6)

# 각 도시에 대한 CircleMarker 추가
for _, row in average_shipping_duration.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['lng']],
        radius=min(row['Shipping Duration'] * 2, 20),  # 배송 기간에 따라 크기 조정
        popup=f"Postal Code: {row['Postal Code']}<br>Avg Shipping Duration: {row['Shipping Duration']:.2f} days",
        color='green',
        fill=True,
        fillColor='green',
        fillOpacity=0.7,
        weight=2
    ).add_to(us_map)

us_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
sns.countplot(x='Postal Code', data=ny_data)
plt.show()

# %%
sns.barplot(
    x='month',
    y='Shipping Duration',
    data=standard_ship
)
plt.show()

# %%
sns.barplot(
    x='Postal Code',
    y='Shipping Duration',
    data=standard_ship
)
plt.show()

# %%
sns.barplot(
    x='Segment',
    y='Shipping Duration',
    data=standard_ship
)
plt.show()

# %%
sns.barplot(
    x='Ship Mode',
    y='Shipping Duration',
    data=ny_data
)
plt.show()

# %%
ny_data.loc[ny_data['Ship Mode']=='Same Day', 'Shipping Duration'].mean()
# Out:
# 0.0

# %%
sns.barplot(
    x='City',
    y='Shipping Duration',
    data=standard_ship
)
plt.show()

# %%
sns.barplot(
    x='Category',
    y='Shipping Duration',
    data=standard_ship
)
plt.show()

# %% [markdown]
# ### 지금까지 중요 Feature
# 1. Ship Mode
# 2. Postal Code?

# %%
corr_matrix=standard_ship.corr(numeric_only=True)

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, 
            annot=True,      # 각 셀에 숫자 표시
            cmap='coolwarm', # 색상 팔레트
            center=0,        # 0을 중심으로 색상 설정
            vmin=-1, 
            vmax=1,
            fmt='.2f')
plt.tight_layout()
plt.show()

# %%
ny_data['Customer ID'].value_counts().nlargest(20)
# Out:
# Customer ID
# SV-20365    14
# AC-10615    13
# NP-18325    10
# PF-19120    10
# DB-13405     9
# PK-19075     8
# GT-14710     8
# KM-16720     8
# CD-12280     8
# DM-13015     7
# EB-13750     7
# EN-13780     7
# SG-20605     7
# MW-18220     7
# KH-16330     7
# LW-17215     7
# AS-10090     7
# DJ-13630     7
# RP-19390     7
# CJ-12010     7
# Name: count, dtype: int64

# %%
keys = ny_data['Customer ID'].value_counts().nlargest(20).index.tolist()

# %%
ny_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1090 entries, 53 to 9781
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1090 non-null   object
#  1   Order Date         1090 non-null   datetime64[ns]
#  2   Ship Date          1090 non-null   datetime64[ns]
#  3   Ship Mode          1090 non-null   object
#  4   Customer ID        1090 non-null   object
#  5   Segment            1090 non-null   object
#  6   City               1090 non-null   object
#  7   Postal Code        1090 non-null   int64
#  8   Product ID         1090 non-null   object
#  9   Category           1090 non-null   object
#  10  Sub-Category       1090 non-null   object
#  11  Product Name       1090 non-null   object
#  12  Sales              1090 non-null   float64
#  13  Shipping Duration  1090 non-null   int64
#  14  lng                1090 non-null   float64
# ...

# %% [markdown]
# **Ship Mode**
# - Same Day: 0
# - First Class: 1
# - Second Class: 2
# - Standard Class: 3

# %%
ny_data['Ship Mode'] = ny_data['Ship Mode'].map({'Same Day': 0, 'First Class': 1, 'Second Class': 2, 'Standard Class': 3})

# %%
ny_data.head()
# Out:
#           Order ID Order Date  Ship Date  Ship Mode Customer ID    Segment  \
# 53  CA-2017-105816 2017-12-11 2017-12-17          3    JM-15265  Corporate
# 54  CA-2017-105816 2017-12-11 2017-12-17          3    JM-15265  Corporate
# 55  CA-2017-111682 2017-06-17 2017-06-18          1    TB-21055   Consumer
# 56  CA-2017-111682 2017-06-17 2017-06-18          1    TB-21055   Consumer
# 57  CA-2017-111682 2017-06-17 2017-06-18          1    TB-21055   Consumer
#
#              City  Postal Code       Product ID         Category Sub-Category  \
# 53  New York City        10024  OFF-FA-10000304  Office Supplies    Fasteners
# 54  New York City        10024  TEC-PH-10002447       Technology       Phones
# 55           Troy        12180  OFF-ST-10000604  Office Supplies      Storage
# 56           Troy        12180  OFF-PA-10001569  Office Supplies        Paper
# 57           Troy        12180  FUR-CH-10003968        Furniture       Chairs
#
# ...

# %%
corr_matrix=ny_data.corr(numeric_only=True)

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, 
            annot=True,      # 각 셀에 숫자 표시
            cmap='coolwarm', # 색상 팔레트
            center=0,        # 0을 중심으로 색상 설정
            vmin=-1, 
            vmax=1,
            fmt='.2f')
plt.tight_layout()
plt.show()

# %%
print(zipCode)
# Out:
# [10024 12180 10009 10035 10801 13021 11757 14609 10011 10550 11572 10701
#  14215 11561 11520 14304 13601 14701 11550 13440 13501]

# %%
# hong_10['vac'] = np.where(
#     (hong_10['월'] == 7) & (hong_10['일'] >= 15) | (hong_10['월'] == 8) & (hong_10['일'] < 20) 
#     | (1 <= hong_10['월']) & (hong_10['월'] <= 2) | (hong_10['월'] == 12) & (hong_10['일'] >= 24),
#     1,
#     0
# )

# %%
len(ny_data['City'].unique())
# Out:
# 18

# %% [markdown]
# > City와 Postal Code 각각 숫자형 카테고리 컬럼 추가

# %%
ny_data['num_City'] = ny_data['City'].astype('category').cat.codes
ny_data.head()
# Out:
#           Order ID Order Date  Ship Date  Ship Mode Customer ID    Segment  \
# 53  CA-2017-105816 2017-12-11 2017-12-17          3    JM-15265  Corporate
# 54  CA-2017-105816 2017-12-11 2017-12-17          3    JM-15265  Corporate
# 55  CA-2017-111682 2017-06-17 2017-06-18          1    TB-21055   Consumer
# 56  CA-2017-111682 2017-06-17 2017-06-18          1    TB-21055   Consumer
# 57  CA-2017-111682 2017-06-17 2017-06-18          1    TB-21055   Consumer
#
#              City  Postal Code       Product ID         Category Sub-Category  \
# 53  New York City        10024  OFF-FA-10000304  Office Supplies    Fasteners
# 54  New York City        10024  TEC-PH-10002447       Technology       Phones
# 55           Troy        12180  OFF-ST-10000604  Office Supplies      Storage
# 56           Troy        12180  OFF-PA-10001569  Office Supplies        Paper
# 57           Troy        12180  FUR-CH-10003968        Furniture       Chairs
#
# ...

# %%
ny_data['num_Postal Code'] = ny_data['Postal Code'].astype('category').cat.codes

# %%
ny_data.head()
# Out:
#           Order ID Order Date  Ship Date  Ship Mode Customer ID    Segment  \
# 53  CA-2017-105816 2017-12-11 2017-12-17          3    JM-15265  Corporate
# 54  CA-2017-105816 2017-12-11 2017-12-17          3    JM-15265  Corporate
# 55  CA-2017-111682 2017-06-17 2017-06-18          1    TB-21055   Consumer
# 56  CA-2017-111682 2017-06-17 2017-06-18          1    TB-21055   Consumer
# 57  CA-2017-111682 2017-06-17 2017-06-18          1    TB-21055   Consumer
#
#              City  Postal Code       Product ID         Category Sub-Category  \
# 53  New York City        10024  OFF-FA-10000304  Office Supplies    Fasteners
# 54  New York City        10024  TEC-PH-10002447       Technology       Phones
# 55           Troy        12180  OFF-ST-10000604  Office Supplies      Storage
# 56           Troy        12180  OFF-PA-10001569  Office Supplies        Paper
# 57           Troy        12180  FUR-CH-10003968        Furniture       Chairs
#
# ...

# %%
ny_data['num_City'].unique()
ny_data['num_Postal Code'].unique()
# Out:
# array([ 2, 12,  0,  3,  6, 13, 11, 19,  1,  4, 10,  5, 17,  9,  7, 18, 16,
#        20,  8, 14, 15], dtype=int8)

# %%
corr_matrix=ny_data.corr(numeric_only=True)

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, 
            annot=True,      # 각 셀에 숫자 표시
            cmap='coolwarm', # 색상 팔레트
            center=0,        # 0을 중심으로 색상 설정
            vmin=-1, 
            vmax=1,
            fmt='.2f')
plt.tight_layout()
plt.show()

# %% [markdown]
# > num_City와 num_Postal Code 모두 Shipping Duration과 직접적인 상관관계는 낮아보인다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
# X_ny = ny_data[['Ship Mode', 'month', 'Weekday', 'num_City', 'num_Postal Code', 'year']]
# X_ny = ny_data[['Ship Mode']]
# X_ny = ny_data[['Ship Mode', 'month', 'num_City', 'num_Postal Code', 'year']]
# X_ny = ny_data[['Ship Mode', 'month', 'Weekday', 'num_City', 'lat', 'lng', 'year']]
# X_ny = ny_data[['Ship Mode', 'month', 'Weekday', 'num_City', 'num_Postal Code']]
X_ny = ny_data[['Ship Mode', 'month', 'Weekday', 'num_Postal Code', 'year']]
y_ny = ny_data['Shipping Duration']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_ny, 
    y_ny, 
    test_size=0.2, 
    random_state=42
)

# %%
rf=RandomForestRegressor(n_estimators=100)

rf.fit(X_train,y_train)
print('Train score:',rf.score(X_train,y_train))
print('Test score:',rf.score(X_test,y_test))
# Out:
# Train score: 0.9666545937008284
# Test score: 0.8558840114271028

# %%
# Decision Tree
dt_model = DecisionTreeRegressor()

# Gradient Boosting
gb_model = GradientBoostingRegressor()

# Gaussian Process
gpr_model = GaussianProcessRegressor()

# K-Neighbors
knn_model = KNeighborsRegressor()

# Extra Trees
et_model = ExtraTreesRegressor()

# %%
dt_model.fit(X_train, y_train)
print('Train score:',dt_model.score(X_train,y_train))
print('Test score:',dt_model.score(X_test,y_test))
# Out:
# Train score: 0.9832104857033177
# Test score: 0.8414490304339347

# %%
gb_model.fit(X_train, y_train)
print('Train score:',gb_model.score(X_train,y_train))
print('Test score:',gb_model.score(X_test,y_test))
# Out:
# Train score: 0.810906801040312
# Test score: 0.7575462894976108

# %%
gpr_model.fit(X_train, y_train)
print('Train score:',gpr_model.score(X_train,y_train))
print('Test score:',gpr_model.score(X_test,y_test))
# Out:
# Train score: 0.9832104856980235
# Test score: 0.627821947302316

# %%
et_model.fit(X_train, y_train)
print('Train score:',et_model.score(X_train,y_train))
print('Test score:',et_model.score(X_test,y_test))
# Out:
# Train score: 0.9832104857033177
# Test score: 0.8792653886888333

# %%
knn_model.fit(X_train, y_train)
print('Train score:',knn_model.score(X_train,y_train))
print('Test score:',knn_model.score(X_test,y_test))
# Out:
# Train score: 0.7765880659508871
# Test score: 0.5518697848798666

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = rf.predict(X_test)

# MSE 계산
mse = mean_squared_error(y_test, y_pred)

# RMSE 계산
rmse = np.sqrt(mse)

print(f"(MSE): {mse}")
print(f"(RMSE): {rmse}")
# Out:
# (MSE): 0.3979504474461898
# (RMSE): 0.630833137561899

# %% [markdown]
# **대부분 Model의 과적합이 크긴 하지만, Ship Mode가 중요한 역할을 하여 70~80%의 예측률을 보여준다.**
# - Ship Mode Column만 이용하여 예측해보니 60% 정도의 예측률을 보였다.

# %% [markdown]
# > hurricane column을 추가해봐도 좋을 것 같다.

# %% [markdown]
# ---
# ### csv 파일 저장

# %%
# ny_data.to_csv('../data/ny_0120.csv', index=False)

# %%
X_ny = ny_data[['Ship Mode', 'month', 'Weekday', 'num_Postal Code', 'year']]
y_ny = ny_data['Shipping Duration']

X_train, X_test, y_train, y_test = train_test_split(
    X_ny, 
    y_ny, 
    test_size=0.2, 
    random_state=42
)

# %%
# Gradient Boosting
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train, y_train)
print('Train score:',gb_model.score(X_train,y_train))
print('Test score:',gb_model.score(X_test,y_test))
# Out:
# Train score: 0.810906801040312
# Test score: 0.7574648350832578
