# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
ny_data = pd.read_csv('../data/ny_0120.csv')
ny_data.head()
# Out:
#          Order ID  Order Date   Ship Date  Ship Mode Customer ID    Segment  \
# 0  CA-2017-105816  2017-12-11  2017-12-17          3    JM-15265  Corporate
# 1  CA-2017-105816  2017-12-11  2017-12-17          3    JM-15265  Corporate
# 2  CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055   Consumer
# 3  CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055   Consumer
# 4  CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055   Consumer
#
#             City  Postal Code       Product ID         Category Sub-Category  \
# 0  New York City        10024  OFF-FA-10000304  Office Supplies    Fasteners
# 1  New York City        10024  TEC-PH-10002447       Technology       Phones
# 2           Troy        12180  OFF-ST-10000604  Office Supplies      Storage
# 3           Troy        12180  OFF-PA-10001569  Office Supplies        Paper
# 4           Troy        12180  FUR-CH-10003968        Furniture       Chairs
#
# ...

# %%
ny_data.head(20)
# Out:
#           Order ID  Order Date   Ship Date  Ship Mode Customer ID  \
# 0   CA-2017-105816  2017-12-11  2017-12-17          3    JM-15265
# 1   CA-2017-105816  2017-12-11  2017-12-17          3    JM-15265
# 2   CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055
# 3   CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055
# 4   CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055
# 5   CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055
# 6   CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055
# 7   CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055
# 8   CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055
# 9   CA-2017-106075  2017-09-18  2017-09-23          3    HM-14980
# 10  CA-2018-161018  2018-11-09  2018-11-11          2    PN-18775
# 11  CA-2018-146780  2018-12-25  2018-12-30          3    CV-12805
# 12  CA-2016-137225  2016-12-15  2016-12-19          3    JK-15640
# ...

# %%
data = pd.read_csv('../data/0116_superstore.csv')
data.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156  2017-11-08  2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156  2017-11-08  2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688  2017-06-12  2017-06-16    Second Class    DV-13045
# 3  US-2016-108966  2016-10-11  2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966  2016-10-11  2016-10-18  Standard Class    SO-20335
#
#      Segment        Country             City       State  Postal Code Region  \
# 0   Consumer  United States        Henderson    Kentucky        42420  South
# 1   Consumer  United States        Henderson    Kentucky        42420  South
# 2  Corporate  United States      Los Angeles  California        90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida        33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida        33311  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
len(data['Postal Code'].unique())
# Out:
# 626

# %% [markdown]
# ---
# ### Hurricane Coloumn 추가
# - 뉴욕 주에 영향을 준 태풍만 추가
# - Order Date 기준으로 생성

# %%
pd.to_datetime(ny_data['Order Date'])
pd.to_datetime(ny_data['Ship Date'])
ny_data.head()
# Out:
#          Order ID  Order Date   Ship Date  Ship Mode Customer ID    Segment  \
# 0  CA-2017-105816  2017-12-11  2017-12-17          3    JM-15265  Corporate
# 1  CA-2017-105816  2017-12-11  2017-12-17          3    JM-15265  Corporate
# 2  CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055   Consumer
# 3  CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055   Consumer
# 4  CA-2017-111682  2017-06-17  2017-06-18          1    TB-21055   Consumer
#
#             City  Postal Code       Product ID         Category Sub-Category  \
# 0  New York City        10024  OFF-FA-10000304  Office Supplies    Fasteners
# 1  New York City        10024  TEC-PH-10002447       Technology       Phones
# 2           Troy        12180  OFF-ST-10000604  Office Supplies      Storage
# 3           Troy        12180  OFF-PA-10001569  Office Supplies        Paper
# 4           Troy        12180  FUR-CH-10003968        Furniture       Chairs
#
# ...

# %%
ny_data['Hurricane'] = np.where(
    (ny_data['Ship Date']>='2016-01-22')&(ny_data['Ship Date']<='2016-01-25')|(ny_data['Ship Date']>='2016-10-08')&(ny_data['Ship Date']=='2016-10-15')|
    (ny_data['Ship Date']>='2017-03-14')&(ny_data['Ship Date']<='2017-03-16')|(ny_data['Ship Date']>='2017-09-19')&(ny_data['Ship Date']<='2017-09-22')|(ny_data['Ship Date']>='2017-10-28')&(ny_data['Ship Date']<='2017-10-31')|
    (ny_data['Ship Date']>='2018-09-08')&(ny_data['Ship Date']<='2018-09-12')|(ny_data['Ship Date']>='2018-10-11')&(ny_data['Ship Date']>='2018-10-14')
    ,
    1,
    0
)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
X_ny = ny_data[['Ship Mode', 'month', 'num_Postal Code', 'year', 'Hurricane']]
# X_ny = ny_data[['Ship Mode']]
# X_ny = ny_data[['Ship Mode', 'month', 'num_City', 'num_Postal Code', 'year']]
# X_ny = ny_data[['Ship Mode', 'month', 'Weekday', 'num_City', 'lat', 'lng', 'year']]
# X_ny = ny_data[['Ship Mode', 'month', 'Weekday', 'num_City', 'num_Postal Code']]
y_ny = ny_data['Shipping Duration']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_ny, 
    y_ny, 
    test_size=0.2, 
    random_state=42
)

# %%
rf=RandomForestRegressor(n_estimators=100)

rf.fit(X_train,y_train)
print('Train score:',rf.score(X_train,y_train))
print('Test score:',rf.score(X_test,y_test))
# Out:
# Train score: 0.9043718318962767
# Test score: 0.7943994593922571

# %%
# Decision Tree
dt_model = DecisionTreeRegressor()

# Gradient Boosting
gb_model = GradientBoostingRegressor()

# Gaussian Process
gpr_model = GaussianProcessRegressor()

# K-Neighbors
knn_model = KNeighborsRegressor()

# Extra Trees
et_model = ExtraTreesRegressor()

# %%
dt_model.fit(X_train, y_train)
print('Train score:',dt_model.score(X_train,y_train))
print('Test score:',dt_model.score(X_test,y_test))
# Out:
# Train score: 0.9167132283334944
# Test score: 0.7562191792187762

# %%
gb_model.fit(X_train, y_train)
print('Train score:',gb_model.score(X_train,y_train))
print('Test score:',gb_model.score(X_test,y_test))
# Out:
# Train score: 0.8085747992803963
# Test score: 0.7522217138119648

# %% [markdown]
# > Hurricane을 Order Date 기준으로 추가하였을 때는 예측률이 미세하게 감소하였지만,
# Ship Date 기준으로 추가하니 1% 미만의 예측률의 상승이 있었다.

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = rf.predict(X_test)

# MSE 계산
mse = mean_squared_error(y_test, y_pred)

# RMSE 계산
rmse = np.sqrt(mse)

print(f"(MSE): {mse}")
print(f"(RMSE): {rmse}")
# Out:
# (MSE): 0.38524296029500094
# (RMSE): 0.6206794344063616

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import matplotlib.pyplot as plt
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
# print('rent')
# # 2. 학습 데이터에 대해 교차검증 수행
# scores = cross_validate(
#     rf, 
#     X_train, 
#     y_train,
#     cv=5,  # 교차검증 폴드 수 지정
#     scoring='r2',  # 평가 지표 지정
#     return_train_score=True  # 훈련 점수도 반환
# )

# # 3. 교차검증 결과 확인
# print(f"교차검증 평균 점수: {np.mean(scores['test_score']):.3f}")
# print(f"교차검증 표준편차: {np.std(scores['test_score']):.3f}")
# print()
# print('return')
# re_scores = cross_validate(
#     rf_re, 
#     X_re_train, 
#     y_re_train,
#     cv=5,  # 교차검증 폴드 수 지정
#     scoring='r2',  # 평가 지표 지정
#     return_train_score=True  # 훈련 점수도 반환
# )

# # 3. 교차검증 결과 확인
# print(f"교차검증 평균 점수: {np.mean(re_scores['test_score']):.3f}")
# print(f"교차검증 표준편차: {np.std(re_scores['test_score']):.3f}")

# %%
ny_data['Product Name'].value_counts().nlargest(20)
# Out:
# Product Name
# Staple envelope                                                                              10
# Easy-staple paper                                                                             8
# Acco Pressboard Covers with Storage Hooks, 9 1/2" x 11", Executive Red                        5
# Ibico EB-19 Dual Function Manual Binding System                                               4
# Eaton Premium Continuous-Feed Paper, 25% Cotton, Letter Size, White, 1000 Shts/Box            4
# Pressboard Data Binders by Wilson Jones                                                       4
# DMI Eclipse Executive Suite Bookcases                                                         4
# GBC Premium Transparent Covers with Diagonal Lined Pattern                                    4
# Xerox 1881                                                                                    4
# O'Sullivan Living Dimensions 5-Shelf Bookcases                                                4
# ...

# %% [markdown]
# 하이퍼파라미터 튜닝
# GridSearchCV, RandomizedSearchCV 사용
# 베이지안 최적화 적용
# 교차 검증
# K-fold 교차 검증 수행
# 정규화 기법 적용
# Ridge, Lasso, ElasticNet 등 사용
# 비선형성 추가
# 다항 특성 추가
# 커널 기반 방법 사용 (SVR 등)
# 데이터 증강
# 부트스트래핑
# SMOTE 등의 기법 활용
# 학습률 조정
# 학습률 스케줄링 적용
# 조기 종료
# 과적합 방지를 위한 조기 종료 기법 사용
# 피처 중요도 분석
# 중요한 특성에 집중하여 모델 개선
# 잔차 분석
# 잔차 플롯을 통한 모델 개선 포인트 파악

# %%
# ny = ny_data[['Ship Mode', 'month', 'Weekday', 'num_City', 'num_Postal Code', 'year', 'Shipping Duration']]
ny = ny_data[['Ship Mode', 'month', 'num_Postal Code', 'year', 'Hurricane']]
# ny = ny_data[['Ship Mode', 'month', 'num_Postal Code', 'year', 'Hurricane']]
target = ny_data['Shipping Duration']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_scaled = scaler.fit_transform(ny)

# %%
from sklearn.decomposition import PCA

# PCA 수행 (2개의 주성분으로 축소)
pca = PCA(n_components=2)
principal_components = pca.fit_transform(data_scaled)

# %%
import matplotlib.pyplot as plt

# PCA 결과 시각화
plt.figure(figsize=(8, 6))
plt.scatter(principal_components[:, 0], principal_components[:, 1], c=target ,cmap='viridis', edgecolor='k', s=50)
plt.title('PCA of Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Target')
plt.grid()
plt.show()

# %%
components = pd.DataFrame(pca.components_, columns=ny.columns, index=['PC1', 'PC2'])
components
# Out:
#      Ship Mode     month  num_Postal Code      year  Hurricane
# PC1   0.056179  0.443339        -0.077088  0.549626   0.701615
# PC2  -0.534167  0.540521         0.489747 -0.419160   0.083393

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(estimator=gb_model, param_grid=param_grid, 
                            cv=10, n_jobs=-1, verbose=2, scoring='r2')

grid_search.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 243 candidates, totalling 2430 fits
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# ...

# %%
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
r2_score = best_model.score(X_test, y_test)
print("Test set r2_score:", r2_score)
# Out:
# Best parameters: {'learning_rate': 0.2, 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Best cross-validation score: 0.8134090246353844
# Test set r2_score: 0.8497112864391503

# %%
from joblib import dump, load

# dump(gb_model, '../Transport/model/gbmodel_ny.joblib')

# %%
plt.figure(figsize=(6, 3))

sns.barplot(data=ny_data[ny_data['Ship Mode']==3], x='month', y='Shipping Duration')

# 그래프 제목과 레이블 설정plt.xlabel('month')
plt.ylabel('Duration')

# x축 레이블 회전
plt.xticks(rotation=45)

# 레이아웃 조정
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

importances = best_model.feature_importances_
feature_names = X_train.columns

plt.barh(feature_names, importances)
plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('Feature Importance')
plt.show()

# %%
# dump(best_model, '../Transport/model/gbmodel_ny.joblib')
# Out:
# ['../Transport/model/gbmodel_ny.joblib']
